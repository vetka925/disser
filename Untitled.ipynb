# %% [markdown]
# # Операции с векторными представлениями слов
#
# Для сопоставительного анализа слов с наиболее близкими контекстами в дистрибутивных моделях русской и башкирской поэзии XX века мы будем использовать gensim и алгоритм Word2Ve.

# %% [markdown]
# Сперва ипортируем необхожимые модули и загрузим уже готовые модели.

# %%
import gensim
import pandas as pd
# %cd "D:\\OneDrive\\Диссертация\\code"

rus_model = gensim.models.Word2Vec.load('distributional_model/data/rus_w2vec.model')
bash_model = gensim.models.Word2Vec.load('distributional_model/data/bash_w2vec.model')

def print_result(word_rus, word_bash):
    df = pd.DataFrame(columns=['rus', 'cosine_sim_rus', 'bash', 'cosine_sim_bash', 'translate'])
    rus = []
    cos_rus = []
    bash = []
    cos_bash = []
    for i in rus_model.most_similar(word_rus, topn=20):
        rus.append(i[0])
        cos_rus.append(i[1])
    df['rus'] = pd.Series(rus)
    df['cosine_sim_rus'] = pd.Series(cos_rus)
    for i in bash_model.most_similar(word_bash, topn=20):
        bash.append(i[0])
        cos_bash.append(i[1])
    df['bash'] = pd.Series(bash)
    df['cosine_sim_bash'] = pd.Series(cos_bash)
    return df
# Out:
# D:\OneDrive\Диссертация\code

# %%
print_result('ветер', 'ел')
# Out:
# C:\Miniconda\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#
# C:\Miniconda\lib\site-packages\ipykernel_launcher.py:19: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#            rus  cosine_sim_rus       bash  cosine_sim_bash translate
# 0         дуть        0.744503    китмәле         0.772807       NaN
# 1        веять        0.681390      китер         0.745157       NaN
# 2        вьюга        0.648650     киткес         0.739972       NaN
# 3       подуть        0.644640      шимал         0.699953       NaN
# 4     попутный        0.627127     төшөрә         0.698949       NaN
# 5      ветерок        0.625582       еләҫ         0.698682       NaN
# 6       буреть        0.604804     елгенә         0.678739       NaN
# ...

# %%
bash_model.similar_by_vector(rus_model['глаз'])
# Out:
# C:\Miniconda\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# C:\Miniconda\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similar_by_vector` (Method will be removed in 4.0.0, use self.wv.similar_by_vector() instead).
#   """Entry point for launching an IPython kernel.
# [('пилот', 0.11636235564947128),
#  ('тәрән', 0.11499668657779694),
#  ('һыҙла', 0.11216641217470169),
#  ('һыҙ', 0.10641651600599289),
#  ('тула', 0.1055903211236),
#  ('һағыш', 0.104537732899189),
#  ('сыңла', 0.10200813412666321),
#  ('буйһонд', 0.09948938339948654),
#  ('ярһы', 0.09676337987184525),
#  ('йот', 0.0955808088183403)]
