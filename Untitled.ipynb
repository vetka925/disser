# %% [markdown]
# # Язык русской и башкирской поэзии XX века в свете дистрибутивного подхода
#
# ***
#
#
#
#
#
# ## <div style="text-align: center">Статистика и язык </div>
#
#
# ### - количественными характеристиками обладают ВСЕ языковые единицы на каждом языковом уровне
#
# ### - качественные характеристики исследуемого объекта имеют цифровое выражение как в единичном ряду, так и во взаимосвязи
#
# ### - статистика как исследовательский инструмент
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# *__Дистрибутивный__ - основывающийся на распределении, дистрибуции.

# %% [markdown]
# # <div style="text-align: center">Подготовка корпуса текстов для исследования</div>
#
# ### - сбор и оцифровка текстов
# ### - разметка
#
# ### - предобработка текстовых данных:
#  <ul>
# ###  <li>графематический анализ (сегмантация и токенизация)
# ###  <li>морфологический анализ (морфологический парсинг)
# ###  <li> <del> синтаксический анализ (синтаксический парсинг)
# ### </ul>
# ###

# %% [markdown]
# # <div style="text-align: center">Токенизация</div>
#
#
# ### - игнорировать\неигнорировать графему заглавности
# ### - игнорировать\неигнорировать неалфавитную графему
# ### - игнорировать\неигнорировать неинформативные "стоп-слова" (предлоги, союзы, личные местоимения, частицы и т.п.)
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ### Загрузим корпус текстов русской и башкирской поэзии.
# ### Загрузим заранее подготовленные дистрибутивные модели для русской и башкирской поэзии.
# ### Импортируем, написанную нами функцию word_tokenize для токенизации текста.
# ### Выберем любые тексты для токенизации.

# %%
import gensim
import pandas as pd

rus_model = gensim.models.Word2Vec.load('distributional_model/data/rus_w2vec.model')
bash_model = gensim.models.Word2Vec.load('distributional_model/data/bash_w2vec.model')
rus_collocations = pd.read_csv('data/rus_collocations.csv')
bash_collocations = pd.read_csv('data/bash_collocations.csv')
translations = pd.read_excel('data/translations.xlsx')
rus_10s = pd.read_csv('data/rus_research_10s.csv')
bash_10s = pd.read_csv('data/bash_10s.csv')

def print_w2vec_result(word_rus, word_bash):
    df = pd.DataFrame(columns=['rus', 'cosine_sim_rus', 'bash', 'cosine_sim_bash', 'translate'])
    rus = []
    cos_rus = []
    bash = []
    translations = []
    cos_bash = []
    for i in rus_model.most_similar(word_rus, topn=20):
        rus.append(i[0])
        cos_rus.append(i[1])
    df['rus'] = pd.Series(rus)
    df['cosine_sim_rus'] = pd.Series(cos_rus)
    for i in bash_model.most_similar(word_bash, topn=20):
        bash.append(i[0])
        cos_bash.append(i[1])
        translations.append(translate(i[0]))
    df['bash'] = pd.Series(bash)
    df['cosine_sim_bash'] = pd.Series(cos_bash)
    df['translate'] = pd.Series(translations)
    return df
def translate(w):
    translation = list(translations[translations.bash == w].ru.values)
    if translation == []:
        return '?'
    else:
        return translation[0]
def print_rus_collocations(w):
    df_col = rus_collocations[rus_collocations.word == w]
    dates = sorted(df_col.date.unique())
    df = pd.DataFrame(columns=dates)
    for d in dates:
        result = []
        collocations = eval(df_col[df_col.date == d].collocation.values[0])
        if len(collocations) > 30:
            collocations = collocations[0:29]
        collocations = [w[0] for w in collocations]
        df[d] = pd.Series(collocations)
    return df
def print_bash_collocations(w):
    df_col = bash_collocations[bash_collocations.word == w]
    dates = sorted(df_col.date.unique())
    df = pd.DataFrame(columns=dates)
    for d in dates:
        result = []
        collocations = eval(df_col[df_col.date == d].collocation.values[0])
        if len(collocations) > 10:
            collocations = collocations[0:9]
        collocations = [w[0]+'//'+translate(w[0]) for w in collocations]
        df[d] = pd.Series(collocations)
    return df
# Out:
# C:\Anaconda\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
from corpus_builder import word_tokenize

rus_poetry = pd.read_csv('data/rus_research.csv')      # корпус русской поэзии XX века
bash_poetry = pd.read_csv('data/bash_poetry_xx.csv')   # корпус башкирской поэзии XX века

rus_poem = rus_poetry.text[0]                          # певрый текст в корпусе русской поэзии XX века
bash_poem = bash_poetry.text[0]                        # певрый текст в корпусе башкирской поэзии XX века

# %%
rus_poetry[rus_poetry.text == rus_poem].author         # узнаем автора текста
# Out:
# 0    Арватов Б.И.
# Name: author, dtype: object

# %%
print(rus_poem)                                       # выведем произведение на экран
# Out:
# ЛЮБОВЬ
# Другу и товарищу А.А. Касаткиной
# Камни планет подымали на камни,
# Стояли, качаясь, на стропилах лучей,
# И радость звенела, дрожала знаменем
# Над водопадами млечных путей.
# А когда / Кометными хвостами
# Нам катастрофы пророчили страх,
# Мы смеялись, встречаясь губами,
# И сильнее / Вздымали / Взмах...
# И снова пролетали мириады километров
# На качелях солнц и планет,
# Нас в лицо целовали циклонные ветры, --
# Архитекторов грядущих лет.
# Люди! / Слушайте, знайте и верьте:
# Не для чуда двух, / Не для праздника звезд, --
# От солнца к солнцу, / От сердца к сердцу
# Мы летим перебросить мост...
# Ну так что же, что жилы порвутся,
# Что не нам / Лавры венков, --
# Мы обвенчаны кровью революций,
# Обручены перед алтарем веков.
# И когда улыбнется улыбкой брата
# Человеческого счастья разлив,
# В пантеонах вселенной засветится атом
# Нашей человеческой любви.
# 1921 г.
# Москва.

# %%
rus_words = word_tokenize(rus_poem, isalpha=True, lower=True, stop=True) # выделим токены в стихотворении 
rus_words[11]                                                            # токен с индексом 11
# Out:
# 'камни'

# %%
bash_poetry[bash_poetry.text == bash_poem].author    # узнаем автора текста
# Out:
# 0    Рәми Ғарипов
# Name: author, dtype: object

# %%
print(bash_poem)                                     # выведем произведение на экран
# Out:
# ﻿ Кәмәлә
# Класташ дуҫтарыма
# Хуш бул, мәктәп!
# Иртәгә — вуз!
# Бөгөн
# Беҙҙең аҫта Иҙел тирбәлә.
# Балҡый кәмәләге дуҫтар йөҙө,
# Ебәк тулҡын йүгерә тирәләп,
# Һөйә ҡояш
# шаян тулҡындарҙы,
# Көҙгә кеүек, Иҙел емелдәй.
# Ҡояш һымаҡ
# уйҙар яҡты беҙҙең,
# Тойғолар ҙа ташыу Иҙелдәй.
# Дуҫтар
# ишә берҙәм,
# көстәр — ташҡын,
# Ярын бара кәмә тулҡынды.
# Уның кеүек
# еңер ҡаршылыҡты
# Берҙәмлеге беҙҙең дуҫлыҡтың.
# Кәмә эҙһеҙ.
# Ләкин
# тормош эҙен
# Йылдар ғына күмә аламы?
# Беҙ бит, дуҫтар,
# ерҙә киләсәкте
# Яҡынайтҡан юлдар һалабыҙ!
# Дуҫтар менән ғүмер —
# яҡты баҡса,
# Һүнмәҫлек дәрт бирә йәшәүең.
# Ҡайҙа ғына
# булһаҡ та беҙ
# Юғалтмайыҡ дуҫлыҡ йәшәүен!
# Дуҫтар
# ишә берҙәм,
# көстәр — ташҡын:
# Ярып бара кәмә тулҡынды.
# Беҙ йырлайбыҙ,
# беҙҙең йырыбыҙға
# Ағиҙел дә түҙмәй ҡушылды.
# Тик һин гүзәл
# бар донъяла,
# Иркен,
# киң Тыуған илем.
# Мең йыл йәшәп булғанда ла
# Мин
# йәшәп
# туймаҫ инем!
#  1950

# %%
bash_words = word_tokenize(bash_poem, isalpha=True, lower=True, stop=True) # выделим токены в стихотворении 
bash_words[2]
# Out:
# 'дуҫтарыма'

# %% [markdown]
# # <div style="text-align: center">Морфологический парсинг русских текстов</div>
#
# ## - pymorphy2
# <br>
#  <ul>
# ###  <li>программа написана на языке программирования Python
# ###  <li>в основе pymorphy2 лежат словари проекта OpenCorpora, которые в свою очередь основаны на грамматическом словаре Зализняка
# ###  <li> алгоритм pymorphy2 сводится к поиску соответствий с лексемами в словаре
# ###  <li> для "несловарных" словоформ алгоритм проверяет перфикс, затем сравнивает остаток с словарными лексемами
# ### </ul>
# ###
# <br>
# Ссылка: Korobov M.: Morphological Analyzer and Generator for Russian and Ukrainian Languages // Analysis of Images, Social Networks and Texts. 2015. – URL: http://link.springer.com/chapter/10.1007%2F978-3-319-26123-2_31 (дата обращения: 15.05.2018).

# %%
import pymorphy2 as pm

ma = pm.MorphAnalyzer()
parsing = ma.parse('камни')
parsing
# Out:
# [Parse(word='камни', tag=OpencorporaTag('NOUN,inan,masc plur,nomn'), normal_form='камень', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'камни', 296, 6),)),
#  Parse(word='камни', tag=OpencorporaTag('NOUN,inan,masc plur,accs'), normal_form='камень', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'камни', 296, 9),))]

# %% [markdown]
# # <div style="text-align: center">Морфологический парсинг башкирских текстов</div>
#
# ## - morphgraph
# ## - в основе программы лежит сетевая модель агглютинативной морфологии
# <img src="pics/pluralis2.png\" alt="Alt text that describes the graphic" title="Title text" />
# ## - алгоритм программы сводится к поиску по направленному графу
# ###  <div style="text-align: center"><i>эшселәрҙеке (башк. принадлежащий рабочим)</i></div>
# <img src="pics/bash_morph.png\" alt="Alt text that describes the graphic" title="Title text" />

# %%
from morphgraph_bash import morph_analysis as ma

par = ma.MorphAnalysis()
parse = par.parsing('дуҫтарыма')
# Out:
# [[('дуҫ', 'S'), ('тар', 'PL'), ('ым', 'POSS,1SG'), ('а', 'DAT')]]

# %% [markdown]
# # <div style="text-align: center">Корпус русской поэзии XX века</div>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %%
rus_poetry
# Out:
#        Unnamed: 0    date             author  \
# 0               0  1921.0       Арватов Б.И.
# 1               1  1921.0     Артамонов М.Д.
# 2               2  1921.0     Бердников Я.П.
# 3               3  1921.0   Волчанецкая Е.Д.
# 4               4  1917.0   Волчанецкая Е.Д.
# 5               5  1921.0   Волчанецкая Е.Д.
# 6               6  1921.0   Волчанецкая Е.Д.
# 7               7  1921.0   Волчанецкая Е.Д.
# 8               8  1921.0   Волчанецкая Е.Д.
# 9               9  1921.0   Волчанецкая Е.Д.
# 10             10  1921.0   Волчанецкая Е.Д.
# 11             11  1921.0   Волчанецкая Е.Д.
# 12             12  1921.0   Волчанецкая Е.Д.
# 13             13  1920.0      Дегтярев Н.В.
# 14             14  1920.0      Дегтярев Н.В.
# 15             15  1921.0        Долныков С.
# 16             16  1920.0  Дорогойченко А.Я.
# 17             17  1920.0  Дорогойченко А.Я.
# 18             18  1922.0        Ерошин И.Е.
# 19             19  1929.0        Ерошин И.Е.
# ...

# %% [markdown]
# ## <div style="text-align: center">Количество текстов</div>

# %%
len(rus_poetry.text)                                        #количество текстов
# Out:
# 49030

# %% [markdown]
# ## <div style="text-align: center">Количество авторов</div>

# %%
len(rus_poetry.author.unique())                            #количество текстов
# Out:
# 467

# %%
frequent_words = pd.read_excel("data/100_freq_w.xlsx")
frequent_words
# Out:
#        Слово  Количество употреблений  Unnamed: 2 Слово.1  \
# 1       быть                    31779           1     бул
# 2       день                    13326           2      ер
# 3       рука                    11982           3     кил
# 4     сердце                    11214           4      ал
# 5      земля                    10823           5      ти
# 6       небо                    10539           6     тор
# 7       ночь                    10145           7      юл
# 8       идти                    10074           8      ит
# 9      жизнь                    10012           9     күр
# 10      глаз                     9719          10     күҙ
# 11      мочь                     9695          11     кит
# 12       мир                     9420          12     ҡал
# 13       год                     9311          13     көн
# 14     знать                     8984          14    ҡара
# 15   человек                     8581          15     йыр
# ...

# %% [markdown]
# # <div style="text-align: center">Корпус башкирской поэзии XX века</div>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %%
bash_poetry
# Out:
#        Unnamed: 0             author    date  \
# 0               0       Рәми Ғарипов  1950.0
# 1               1       Рәми Ғарипов  1950.0
# 2               2       Рәми Ғарипов  1950.0
# 3               3       Рәми Ғарипов  1950.0
# 4               4       Рәми Ғарипов  1950.0
# 5               5       Рәми Ғарипов  1950.0
# 6               6       Рәми Ғарипов  1950.0
# 7               7       Рәми Ғарипов  1950.0
# 8               8       Рәми Ғарипов  1950.0
# 9               9       Рәми Ғарипов  1951.0
# 10             10       Рәми Ғарипов  1951.0
# 11             11       Рәми Ғарипов  1951.0
# 12             12       Рәми Ғарипов  1951.0
# 13             13       Рәми Ғарипов  1951.0
# 14             14       Рәми Ғарипов  1951.0
# 15             15       Рәми Ғарипов  1951.0
# 16             16       Рәми Ғарипов  1952.0
# 17             17       Рәми Ғарипов  1952.0
# 18             18       Рәми Ғарипов  1952.0
# 19             19       Рәми Ғарипов  1952.0
# ...

# %%
len(bash_poetry.text)
# Out:
# 16080

# %%
len(bash_poetry.author.unique())
# Out:
# 97

# %% [markdown]
# # <div style="text-align: center">Дистрибутивная модель</div>
#
# ## - векторное предствление слов, основанное на статистике распределения слов в контексте
# ## - абстрактная когнитивная структура, которая складывается из употреблений слова в различных лингвистических контекстах
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # <div style="text-align: center"> Дистрибутивная гипотеза:</div>
# ### Степень семантической близости между двумя лингвистическими единицами А и В есть функция схожести лингвистических контекстов, в которых могут употребляться А и В
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # <div style="text-align: center">Ключевые слова</div>
#
# ## - лексические доминанты в определенный период времени
# ## - понимание языковой картины мира
# ## - отражение социально-политической ситуации
# ## - отражение национально-специфических черт концептуализации действительности
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## <div style="text-align: center">Мера TF-IDF для извлечения ключевых слов</div>
#
# $$ TF-IDF=TF\left(t,d\right)\cdot IDF\left(n,N\right) $$
# ### Где словоформа t и текст d принадлежат D – корпусу текстов, где t употребляется в n текстах из общего количества текстов N в корпусе D.
#
# $$ tf(t,d)=\frac{n_i}{\mathrm{\Sigma}_kn_k} $$
# ### Где n_i – число вхождений слова t в текст d, $$ \mathrm{\Sigma}_kn_k $$ – сумма вхождений всех слов в данном тексте d, или общее число слов в тексте d.
#
# $$ idf(n,N)=\log{\left(\frac{N}{n}\right)} $$
# ### Где N – общее количество текстов d в корпусе D, a n – количество текстов, в которых употребляется словоформа t. Логарифм отношения $$ \frac{N}{n} $$ используется для нормализации значений
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # <div style="text-align: center">Ключевые слова 1910-х годов русской поэзии</div>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %%
', '.join(rus_10s[rus_10s.date == 1910].author.unique())        # авторы первого десятилетия XX века
# Out:
# 'Добролюбов А.М., Анненский И.Ф., Асеев Н.Н., Лившиц Б.К., Бобров С.П., Зданевич И.М., Чурилин Т.В., Ахматова А.А., Ахматова А.А. | dubium, Бальмонт К.Д., Балтрушайтис Ю.К., Белый А. (Бугаев Б.Н.), Блок А.А., Блок А.А. | соавторы, Брюсов В.Я., Бунин И.А., Бурлюк Д.Д., Бурлюк Н.Д., Черный С. (Гликберг А.М.), Дмитриева Е.И., Дмитриева Е.И. (Черубина де Габриак), Цветаева М.И., Эренбург И.Г., (Кобылинский Л.Л.) Эллис, Цетлин М.О. (Амари), Голохвастов Г.В., Позняков Н.С., Маковский С.К., Есенин С. А., Герцык А.К., Гиппиус З.Н., Иванов Г.В., Гофман В.В., Горький М. (А.М.Пешков), Городецкий С.М., Гумилев Н.С., Гуро Е.Г., Клюев Н.А., Клычков С.А., Комаровский В.А., Кондратьев А.А., Толстой А.Н., Крандиевская Н.В., Кузмин М.А., Мандельштам О.Э., Киссин С.В., Нарбут В.И., Пастернак Б.Л., Полонская Е.Г., Садовской Б.А., Зальцман П.Я. | Зальцман Я.Я., Потемкин П.П., Князев В.В., Венский Е. (Пяткин Е.О.), Горный С. (Оцуп А.А.), Красный (Антипов К.М.), Прутков И.К. (Жиркович Б.В.), Тэффи (Лохвицк
# ...

# %% [markdown]
# ## Глаголы:
# ### <i>манить, взглянуть, веять, молиться, застыть, блистать, рыдать, дрогнуть, дремать, склониться, озарить, влечь.
#
#
# ## Прилагательные:
# ### <i>страстный, незримый, прежний, безмолвный, ласковый, лазурный, страстный, желанный, царский, радостный, робкий, унылый, мятежный, безбрежный, лучистый, пламенный, алый, золотистый, вешний, стройный, томный, влажный, покорный.
#
#
# ## Наречия:
# ### <i>нежно, ныне, прочь.
#
#
# ## Существительные:
# ### <i>угодник, грёза, вьюга, корифей, змей, стрела, одежда, свод, сонм, нива, владыка, кормилица, кудри, гном, поцелуй, змея, нимфа, маска, ступень, лобзание, прибрежье, замок, лука, бобр, чело, венка, вестник, гера, блаженство, орфей, прозрачность, фея, дафнис, мечтание, сонет, молитва, плена, алтарь, касьян, колдунья, посейдон, рабыня, терем, скал, дочь, хлой, ася, объятие, венец, аглая, гобелен, бег, царевна, гимн, брег, пирог, лазурь, рыцарь, лилия, поток, царица, порыв, гертруда, хор, чертог, нега, кольцо, долина, виденье, демон, король, конюх, обет, федя, узор, мыза, подвижник, ласка, дол.
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## - абстрактная лексика
# ## - образность
# ## - религиозная и мифологическая лексика
# ## - книжная лексика, устаревшие слова
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # <div style="text-align: center">Ключевые слова 1910-х годов башкирской поэзии</div>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %%
bash_poetry[bash_poetry.date.apply(lambda d: d in range(1900,1911))].author.unique()     # авторы первого десятилетия XX века
# Out:
# array(['Мәжит Ғафури', 'Дауыт Юлтый'], dtype=object)

# %% [markdown]
# ## глаголы:
# ### тырыш (стараться);
#
# ## прилагательные:
# ### матур (красивый), тиҙ (быстрый), фәҡир (бедный, убогий), бисара (несчастный), насар (плохой), бәғзе (неопределенный, некоторый), яман (страшный), төҫлө (цветной);
#
# ## существительные:
# ### заман (время), ғилем (знание), милләт (нация), файҙа (польза), мәғариф (образование), мәктәп (школа), тәрбиә (воспитание), ур (ров с валом, вор, жулик), һиммәт (вдохновение, честь), дошман (враг), шәкерт (студент), иҫ (чувство, сознание, память), фекер (мысль), гөнаһ (грех),  бәндә (раб, человечишка), хаҡ (право, плата), ислах (реформа), ҡылған (ковыль), мосолман (мусульманин), ҡыҫала (рак), сәғәҙә (счастье, достаток), һәр кеше (каждый человек);
#
# ### и старотюркские слова:
# ### кеби (послелог подобно), бән (я), берлә (с).
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## - часть КС относится к политическому дискурсу
# ## - присутствует религиозная лексика
# ## - количество прилагательных значительно меньше
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <

# %% [markdown]
# # <div style="text-align: center">Ключевые слова 1920-х годов русской поэзии</div>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## Глаголы:
# ### блистать, веять, покинуть, молиться.
#
# ## Прилагательные:
# ### сладостный, стройный, дивный, мутный, алый, буйный, радостный, рыжебородый, молотый, огненный, вешний, пламенный, ласковый, мудрый.
#
# ## Наречие: нежно.
#
# ## Существительные:
# ### грёза, жребий, иван, стрела, свод, пермь, нева, маркиз, нива, магдалина, дед, поцелуй, дофин, невский, рим, сосна есть, маша, алеша, игрок, знамя, коммуна, городишко, железо, скорбь, тундра, иран, паж, молитва, принцесса, алтарь, скал, дочь, никола, завод, есмить, борьба, пение, бег, царевна, серафим, воин, роса, самовар, явь, князь, лазурь, кирпичик, поток, царица, луи, певец, песнопевец, домбра, павиан, кудесник, христос, рабочий, кольцо, виденье, изба, король, революция, трепет, кадет, федя, дама, ласка, париж, плащ, антип.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## - появляются КС относящиеся к политическому и военному дискурсу (Революция 1917 года)
# ## - все еще присутствует религиозная лексика
# ## - все еще присутствует образность
# ## - среди КС возникает общеупотребительная лексика, связанная с бытом города и деревни
# ## - появление имен собственных и топонимов
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # <div style="text-align: center">Ключевые слова 1920-х годов башкирской поэзии</div>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## Глаголы:
# ### тын (затихать), туҡта (остановиться), алда (врать), күтәр (поднять), йырла (петь), ҡапла (закрыть), ҡалҡ (всходить), ташла (кинуть), эшлә (работать).
#
# ## Прилагательные:
# ### төҫлө (цветной), яҡты (светлый), ҡыҙыл (красный), һуңғы (поздний), яҙғы (весенний), яңы (новый).
#
# ## Существительные:
# ### ҡыр (край), сәскә (цветок), иҫ (чувство, сознание, память), хис (чувство), болот (облако), йөрәг (сердце), дошман (враг), баҫыу (нажим, пашня), үр (подъем, высота), мөхәббәт (любовь), үлем (смерть, кончина), боҙ (лед), шау (шум), еҫ (запах), бүре (волк), шишмә (родник), минут (минута), ямғыр (дождь), һөйөү (любовь, ласка), офоҡ (горизонт), ҡайын (береза), көрәш (борьба), ҡылыс (сабля, меч), һағыш (тоска, грусть).
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## - возникают КС, описывающие чувства, эмоции и их восприятие
# ## - пейзажные образы
# ## - среди КС появляется военная лексика
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %%
print_w2vec_result('борьба', 'көрәш')
# Out:
# C:\Miniconda\lib\site-packages\ipykernel_launcher.py:18: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
# C:\Miniconda\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#             rus  cosine_sim_rus      bash  cosine_sim_bash  \
# 0         месть        0.912534        ең         0.867060
# 1        подвиг        0.899148    партия         0.853240
# 2      победить        0.896357      көрә         0.845422
# 3     поражение        0.869646     бурыс         0.818226
# 4        година        0.865566    берҙәм         0.814164
# 5         битва        0.865498     тупла         0.813369
# 6         окова        0.865405    хеҙмәт         0.803781
# 7        вражда        0.863778     данлы         0.803290
# 8   беспощадный        0.863508      эшсе         0.799600
# ...

# %% [markdown]
# # <div style="text-align: center">Ключевые слова 1950-х годов русской поэзии</div>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## Глаголы:
# ### вопрошать, лаяться, еcть, cказать, пеленать, cтоять.
#
# ## Прилагательные:
# ### питерский, ленинградский, свеча горелый, родимый, московский, круглый, немецкий, фронтовой.
#
# ## Существительные:
# ### лукоморье, свист, дружба, ганс, немец, инфанта, ленинград, иван, запад, ленинградец, гудение, полка, парень, cвета, майор, холоп, азербайджан, петров, тир, ад, колокол, крым, мадрид, зенитка, москва, фронт, штык, ребята, коммунар, илья, коммуна, гамма, взвод, cлов, товарищ, каспий, анна, блокада, cолнце, кузьма, равноправие, снаряд, данте, прощение, боец, берлин, выходить балкон, фашист, автомат, махина, войско, исключение, шах, пароходик, cвой, юный голос, пpиpода, роса, школа, салют, верочка, cеpдец, василий, cияние, пустельга, тамань, данте, лиcт, рабочий, пуля, царство божий, страшный путь, cудьба, глагол, хорда, танк, пушка, cтол, дед.
#
# ## Наречие: далеко.

# %% [markdown]
# ## - КС отражают доминирующую тему: "война"
# ## - снова появляется религиощная лексика "ад - царство божье"
# ## - Данте
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # <div style="text-align: center">Ключевые слова 1950-х годов башкирской поэзии</div>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## Глаголы:
# ### үҫ (расти), тын (затихать), күтәр (поднять), йырла (петь), туҡта (остановиться), ташла (кинуть).
#
# ## Прилагательные:
# ### матур (красивый), алтын (золотой), яҡты (светлый), яңы (новый), төҫлө (цветной), яҡын (близкий), һуңғы (поздний), совет (советский), ҡайнар (кипящий), бөйөк (великий), зәңгәр (голубой),  тәүге (ранний, первый), һай (мелкий).
#
# ## Существительные:
# ### дошман (враг), ҡыр (край), сәскә (цветок), ватан (отечество), һалдат (солдат), ленин (Ленин), хеҙмәт (труд, произведение, служба), фашист (фашист), иҫ (чувство, сознание, память), ҡылыс (сабля, меч),  үлем (смерть, кончина), йөрәг (сердце), мәскәү (петля, оборка), еңеү (победа), мөхәббәт (любовь), иптәш (товарищ), баҡса (огород), иген (зерно), болот (облако, губка), ялан (поле), ҡайын (береза), баҫыу (нажим, пашня), һөйөү (любовь, ласка), партия (партия), колхоз (колхоз), ҡый (сор, мусор, сорняк).
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## - военная лексика
# ## - лексика, связанная с сельским хозяйством
# ## - качественные прилагательные
# ## - идеологичность
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %%
print_w2vec_result('враг', 'дошман')
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:17: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:22: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#           rus  cosine_sim_rus     bash  cosine_sim_bash  \
# 0      верный        0.754112     яуыз         0.814923
# 1    победить        0.721946       үс         0.810521
# 2        боец        0.713459   фашист         0.800409
# 3     грозить        0.710100   ғәскәр         0.784421
# 4      оружие        0.707246   ҡыйрат         0.763980
# 5      недруг        0.702306    ҡорал         0.758682
# 6        воин        0.701912    фашис         0.747540
# 7     сразить        0.700995     үлем         0.742126
# 8      доведь        0.693200   ябырыл         0.734766
# ...

# %% [markdown]
# # Анализ некоторых понятий (концептов), отраженных в поэтических текстах XX века
#
#
# ### 1. Счастье
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %%
print_w2vec_result('счастие', 'бәхет')
# Out:
# C:\Miniconda\lib\site-packages\ipykernel_launcher.py:18: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
# C:\Miniconda\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#               rus  cosine_sim_rus       bash  cosine_sim_bash  \
# 0         радость        0.860869        юра         0.723995
# 1         надежда        0.791008    бәхетле         0.703320
# 2          утрата        0.743648      юлдаш         0.669611
# 3      счастливый        0.737177       өләш         0.666322
# 4       молодость        0.736877      теләп         0.663924
# 5         суждено        0.736315    ҡыуаныс         0.662345
# 6      блаженство        0.735021       роме         0.652602
# 7            любя        0.731937     ышаныс         0.649531
# ...

# %% [markdown]
# # Анализ некоторых понятий (концептов), отраженных в поэтических текстах XX века
#
#
# ### 2. Поэт
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %%
print_w2vec_result('поэт', 'шағир')
# Out:
# C:\Miniconda\lib\site-packages\ipykernel_launcher.py:18: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
# C:\Miniconda\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#            rus  cosine_sim_rus          bash  cosine_sim_bash  \
# 0        проза        0.841903          туҡа         0.824806
# 1       поэзия        0.829604         хаҡлы         0.792911
# 2       пушкин        0.815184         пушки         0.785903
# 3        автор        0.814505           тур         0.777647
# 4     сочинять        0.809915         үлмәҫ         0.772549
# 5      повесть        0.798778       кобзарь         0.765587
# 6       пример        0.796675         данла         0.753024
# 7     гадатель        0.792654          ысын         0.752034
# ...

# %% [markdown]
# # Анализ некоторых понятий (концептов), отраженных в поэтических текстах XX века
#
#
# ### 3. "Пить"
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %%
print_w2vec_result('пить', 'эс')
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:19: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
# C:\Anaconda\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:24: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#          rus  cosine_sim_rus      bash  cosine_sim_bash  \
# 0     выпить        0.894750    шәрбәт         0.941575
# 1       вино        0.855507     уртла         0.930612
# 2     стакан        0.821125      тәме         0.923778
# 3      чаять        0.809718     зәмзә         0.922741
# 4      водка        0.800978     эстек         0.917741
# ...

# %% [markdown]
# # Анализ некоторых понятий (концептов), отраженных в поэтических текстах XX века
#
#
# ### 4. "башкир" - для русских поэтов. "рус" - для башкирских поэтов.
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %%
print_w2vec_result('башкир', 'рус')
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:19: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
# C:\Anaconda\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:24: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#             rus  cosine_sim_rus        bash  cosine_sim_bash  \
# 0      нехристь        0.987976       татар         0.909606
# 1       душегуб        0.987567     башҡорт         0.901294
# 2        энтота        0.987363     товарищ         0.860738
# 3    трисмегист        0.986760      тройка         0.855943
# ...

# %%
print_rus_collocations('водка')
# Out:
#            1910            1920         1930        1940          1950  \
# 0          пить            пить         пить        пить          пить
# 1          крем       вихляться        грязь  выхлестать      обпиться
# 2    управитель      управиться      посеять      закусь  стограммовый
# 3        коньяк        нацедить    продавать       балык      угощение
# 4       портить      полюбиться      ерофеич    бесценок     цинандали
# 5   приголубить         паллада       икорка    колбаска      хрипнуть
# 6      хлопнуть       похвалить   нализаться      валять       римляна
# 7    заплескать  свирепствовать  омолодиться      фараон     грозиться
# 8       лопнуть       трухлявый       споить   иноземный       пьяница
# 9       глушить       процедить       глотка      коньяк      холостой
# 10         пиво          пожить    въедливый      девать       гулянка
# 11      бутылка         болтать       маклер      эполет        кошмар
# ...
